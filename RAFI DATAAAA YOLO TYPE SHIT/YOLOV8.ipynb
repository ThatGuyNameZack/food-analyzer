# %%
from roboflow import Roboflow
rf = Roboflow(api_key="soA5fxoQOule3Hph9S9P")
project = rf.workspace("tristan-2bilf").project("indonesian-food-cmrvt")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
import random
import itertools
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image , Video , display
import requests

# %%
img_dir = "C:\\Users\\Tristan\\Documents\\File_Kampus\\Sem_3\\Research\\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\\Indonesian-Food-5\\train\\images"
n_samples = 9
img_files = os.listdir(img_dir)
rand_imgs = random.sample(img_files , n_samples)
fig , axes = plt.subplots(3,3, figsize=(11,11))

for i in range(n_samples):
  img = rand_imgs[i]
  ax = axes[i // 3, i % 3]
  ax.imshow(plt.imread(os.path.join(img_dir, img)))
  ax.axis('off')
  # Take the name before the first underscore
  title = img.split('_')[0]
  ax.set_title(title)

plt.tight_layout
plt.show()

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
model = YOLO("yolov8m.pt")  # Load a pretrained YOLOv8 model
result = model.train(data='C:\\Users\\Tristan\\Documents\\File_Kampus\\Sem_3\\Research\\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\\Indonesian-Food-5\\data.yaml', epochs=30, imgsz=640, batch=16, device='0')
# Out:
# New https://pypi.org/project/ultralytics/8.3.150 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.140  Python-3.13.0 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
# Validate the trained YOLO model on the validation set
val_results = model.val(data='C:\\Users\\Tristan\\Documents\\File_Kampus\\Sem_3\\Research\\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\\Indonesian-Food-5\\data.yaml', device='0')
print(val_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Validate the trained YOLO model on the validation set
# ----> 2 val_results = model.val(data='C:\\Users\\Tristan\\Documents\\File_Kampus\\Sem_3\\Research\\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\\Indonesian-Food-5\\data.yaml', device='0')
#       3 print(val_results)
#
# NameError: name 'model' is not defined

# %%
# Test the trained YOLO model on the test set
test_results = model.val(split='test', data='C:\\Users\\Tristan\\Documents\\File_Kampus\\Sem_3\\Research\\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\\Indonesian-Food-5\\data.yaml', device='0')
print(test_results)
# Out:
# Ultralytics 8.3.140  Python-3.13.0 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# val: Fast image access  (ping: 0.40.2 ms, read: 2.91.3 MB/s, size: 70.0 KB)
# val: Scanning C:\Users\Tristan\Documents\File_Kampus\Sem_3\Research\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\Indonesian-Food-5\test\labels... 570 images, 3 backgrounds, 0 corrupt: 100%|██████████| 570/570 [00:02<00:00, 202.55it/s]
# val: New cache created: C:\Users\Tristan\Documents\File_Kampus\Sem_3\Research\YOLO TRAINING BUT USING THE DATA THAT RAFI GIVE\Indonesian-Food-5\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 36/36 [00:15<00:00,  2.30it/s]
#                    all        570        686      0.891      0.878      0.904      0.607
#            Ayam Goreng         44        125      0.509       0.49      0.425      0.201
# ...

# %%
print(f"Mean F1-score: {f1_score.mean():.4f}")
print(f"Mean Accuracy: {accuracy.mean():.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(f"Mean F1-score: {f1_score.mean():.4f}")
#       2 print(f"Mean Accuracy: {accuracy.mean():.4f}")
#
# NameError: name 'f1_score' is not defined
