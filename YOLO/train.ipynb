# %%
from ultralytics import YOLO
import random
import itertools
import os
import numpy as pd
import matplotlib.pyplot as plt
from IPython.display import Image , Video , display
import requests

# %%
img_dir = "C:/Users/Tristan/Documents/File_Kampus/Sem_3/Research/YOLO_Dataset/train/images"

n_samples = 9
img_files = os.listdir(img_dir)
rand_imgs = random.sample(img_files , n_samples)
fig , axes = plt.subplots(3,3, figsize=(11,11))

for i in range(n_samples):
  img = rand_imgs[i]
  ax = axes[i//3 , i%3]
  ax.imshow(plt.imread(os.path.join(img_dir ,img)))
  ax.axis('off')
  ax.set_title(f"Image {i+1}")

plt.tight_layout
plt.show()

# %% [markdown]
# # Train YoloV8

# %%
model = YOLO("yolov8m.pt")  # Load a pretrained YOLOv8 model
result = model.train(data='C:/Users/Tristan/Documents/File_Kampus/Sem_3/Research/YOLO_Dataset/data.yaml', epochs=30, imgsz=640, batch=16, device='0')
# Out:
# New https://pypi.org/project/ultralytics/8.3.147 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.140  Python-3.13.0 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
import os
print(os.path.exists(r"c:\Users\Tristan\Documents\File Kampus\Sem 3\Research\YOLO Dataset\Tugas-Besar-Siscer-1\data.yaml"))
# Out:
# False

# %%
metrics = model.val()
for k, v in metrics.results_dict.items():
    print(f"{k}: {v}")
# Out:
# Ultralytics 8.3.140  Python-3.13.0 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 92 layers, 25,847,287 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 315.4397.5 MB/s, size: 134.5 KB)
# val: Scanning C:\Users\Tristan\Documents\File_Kampus\Sem_3\Research\YOLO_Dataset\valid\labels.cache... 69 images, 0 backgrounds, 0 corrupt: 100%|██████████| 69/69 [00:00<?, ?it/s]
# WARNING Box and segment counts should be equal, but got len(segments) = 7, len(boxes) = 111. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:12<00:00,  2.43s/it]
#                    all         69        111       0.69      0.784      0.784      0.513
# ...
